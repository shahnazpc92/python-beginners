# %%
# python -m pip install textblob tweepy matplotlib

from textblob import TextBlob
import sys, tweepy
import matplotlib.pyplot as plt

def percentage(part,whole):
    return 100 * float(part)/float(whole)

consumerKey = "MfnDQ8TXg1Bzf7LfCiUNYyAdC"
consumerSecret = "0MZuGJXDn3iyPoMsjIiUulMcAFm8CBPktQDcCvqgcGZnr3cz5D"
accessToken = "2336835024-LXdx3pacMVpPjHdxWv33ytByZ8PtAzsh5sePRIg"
accessTokenSecret = "4Vshr1EDOftsHfYlj3B11b7dYi7r6Q2cDXOE8i3b5Okyl"

auth = tweepy.OAuthHandler(consumer_key=consumerKey, consumer_secret=consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

searchTerm = input("Enter Keyword/Hashtag to search about: ")
noOfSearchTerms = int(input("Enter how many tweets to analyze: "))

tweets = tweepy.Cursor(api.search, q=searchTerm, lang="en").items(noOfSearchTerms)

positive = 0
negative = 0
neutral = 0
polarity = 0

for tweet in tweets:
    #print(tweet.text)
    analysis = TextBlob(tweet.text)
    polarity += analysis.sentiment.polarity
   
    if(analysis.sentiment.polarity == 0):
        neutral += 1
    elif(analysis.sentiment.polarity < 0.00):
        negative += 1
    elif(analysis.sentiment.polarity > 0.00):
        positive += 1
        
positive = percentage(positive, noOfSearchTerms)
negative = percentage(negative, noOfSearchTerms)
neutral = percentage(neutral, noOfSearchTerms)

positive = format(positive, '.2f')
neutral = format(neutral, '.2f')
negative = format(negative, '.2f')

print("How people are reacting on " + searchTerm + " by analyzing " + str(noOfSearchTerms) + " Tweets.")

if(polarity == 0):
    print("Neutral")
elif(polarity < 0):
    print("Negative")
elif(polarity > 0):
    print("Positive")
    
labels =['Positive ['+str(positive)+'%]','Neutral['+str(neutral)+'%]','Negative['+str(negative)+'%]']
sizes = [positive,neutral,negative]
colors = ['yellowgreen','gold','red']
patches,text = plt.pie(sizes, colors=colors, startangle=90)
plt.legend(patches,labels,loc="best")
plt.title("How people are reacting on " + searchTerm + " by analyzing " + str(noOfSearchTerms) + " Tweets.")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Enter Keyword/Hashtag to search about: trump
# Enter how many tweets to analyze: 100
# How people are reacting on trump by analyzing 100 Tweets.
# Negative

# %%
import pandas as pd

# %%
htmlfile = pd.read_table('home.html')

# %%
htmlfile
# Out:
#                                        <!DOCTYPE html>
# 0                                               <html>
# 1                                               <head>
# 2                               <meta charset="utf-8">
# 3         <title>Medic | Medical HTML Template</title>
# 4                      <!-- mobile responsive meta -->
# 5      <meta name="viewport" content="width=device-...
# 6      <meta name="viewport" content="width=device-...
# 7                              <!-- Slick Carousel -->
# 8      <link rel="stylesheet" href="plugins/slick/s...
# 9      <link rel="stylesheet" href="plugins/slick/s...
# 10                                   <!-- FancyBox -->
# 11     <link rel="stylesheet" href="plugins/fancybo...
# 12                                <!-- Stylesheets -->
# 13        <link href="css/style.css" rel="stylesheet">
# 14                                      <!--Favicon-->
# 15     <link rel="shortcut icon" href="images/favic...
# 16     <link rel="icon" href="images/favicon.ico" t...
# 17                                             </head>
# 18                                              <body>
# 19                          <div class="page-wrapper">
# 20                                  <!-- Preloader -->
# 21              <!-- <div class="preloader"></div> -->
# 22                                  <!-- Preloader -->
# 23                                   <!--header top-->
# 24                            <div class="header-top">
# 25                    <div class="container clearfix">
# 26                              <div class="top-left">
# 27                     <h6>Opening Hours : Saturday...
# 28                                              </div>
# 29                             <div class="top-right">
# ..                                                 ...
# 387                 <a href="contact.html">Contact</a>
# 388                                              </li>
# 389                                              </ul>
# 390                                             </div>
# 391                                             </div>
# 392                                          </footer>
# 393                             <!--End footer-main-->
# 394                                             </div>
# 395                             <!--End pagewrapper-->
# 396                               <!--Scroll to top-->
# 397  <div class="scroll-to-top scroll-to-target" da...
# 398          <span class="icon fa fa-angle-up"></span>
# 399                                             </div>
# 400          <script src="plugins/jquery.js"></script>
# 401   <script src="plugins/bootstrap.min.js"></script>
# 402  <script src="plugins/bootstrap-select.min.js">...
# 403                              <!-- Slick Slider -->
# 404  <script src="plugins/slick/slick.min.js"></scr...
# 405                                  <!-- FancyBox -->
# 406  <script src="plugins/fancybox/jquery.fancybox....
# 407                                <!-- Google Map -->
# 408  <script src="https://maps.googleapis.com/maps/...
# 409  <script src="plugins/google-map/gmap.js"></scr...
# 410        <script src="plugins/validate.js"></script>
# 411             <script src="plugins/wow.js"></script>
# 412       <script src="plugins/jquery-ui.js"></script>
# 413      <script src="plugins/timePicker.js"></script>
# 414               <script src="js/script.js"></script>
# 415                                            </body>
# 416                                            </html>
#
# [417 rows x 1 columns]

# %%
# %load 'E:\WEBSITE Project\ADMIN Colored'
E:\WEBSITE Project\ADMIN Colored

# %%
# %load 'E:\WEBSITE Project\ADMIN Colored\home.html'
E:\WEBSITE Project\ADMIN Colored\home.html

# %%
# %run 'home.html'
# Out:
# ERROR:root:File `"'home.html'.py"` not found.
