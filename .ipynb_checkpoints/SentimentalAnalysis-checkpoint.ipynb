# %%
# python -m pip install textblob tweepy matplotlib

from textblob import TextBlob
import sys, tweepy
import matplotlib.pyplot as plt

def percentage(part,whole):
    return 100 * float(part)/float(whole)

consumerKey = "MfnDQ8TXg1Bzf7LfCiUNYyAdC"
consumerSecret = "0MZuGJXDn3iyPoMsjIiUulMcAFm8CBPktQDcCvqgcGZnr3cz5D"
accessToken = "2336835024-LXdx3pacMVpPjHdxWv33ytByZ8PtAzsh5sePRIg"
accessTokenSecret = "4Vshr1EDOftsHfYlj3B11b7dYi7r6Q2cDXOE8i3b5Okyl"

auth = tweepy.OAuthHandler(consumer_key=consumerKey, consumer_secret=consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

searchTerm = input("Enter Keyword/Hashtag to search about: ")
noOfSearchTerms = int(input("Enter how many tweets to analyze: "))

tweets = tweepy.Cursor(api.search, q=searchTerm, lang="en").items(noOfSearchTerms)

positive = 0
negative = 0
neutral = 0
polarity = 0

for tweet in tweets:
    #print(tweet.text)
    analysis = TextBlob(tweet.text)
    polarity += analysis.sentiment.polarity
   
    if(analysis.sentiment.polarity == 0):
        neutral += 1
    elif(analysis.sentiment.polarity < 0.00):
        negative += 1
    elif(analysis.sentiment.polarity > 0.00):
        positive += 1
        
positive = percentage(positive, noOfSearchTerms)
negative = percentage(negative, noOfSearchTerms)
neutral = percentage(neutral, noOfSearchTerms)

positive = format(positive, '.2f')
neutral = format(neutral, '.2f')
negative = format(negative, '.2f')

print("How people are reacting on " + searchTerm + " by analyzing " + str(noOfSearchTerms) + " Tweets.")

if(polarity == 0):
    print("Neutral")
elif(polarity < 0):
    print("Negative")
elif(polarity > 0):
    print("Positive")
    
labels =['Positive ['+str(positive)+'%]','Neutral['+str(neutral)+'%]','Negative['+str(negative)+'%]']
sizes = [positive,neutral,negative]
colors = ['yellowgreen','gold','red']
patches,text = plt.pie(sizes, colors=colors, startangle=90)
plt.legend(patches,labels,loc="best")
plt.title("How people are reacting on " + searchTerm + " by analyzing " + str(noOfSearchTerms) + " Tweets.")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Enter Keyword/Hashtag to search about: bitcoin
# Enter how many tweets to analyze: 100
# RT @cryptoshion: 🎁0.001 $BTC  &amp; 1000 $MMO #giveaway
#
# ⏩Rules to Participate:
# Follow  us, @MMOProOfficial &amp; @Osaidbk
#
# ✅Like &amp; RT this.
# ✅Tag…
# RT @DrBitcoinMD: The #Bitcoin HODLer manifesto:
#
# 1. Never sell for fiat
# 2. Buy the dip
# 3. Disregard FUD
# 4. Not your keys, not your coins
# 5.…
# RT @binance: Tick-tock #Bitcoin.
#
# ⏲️ https://t.co/YncS517mAc https://t.co/KoKLXBUs2f
# RT @RedvixCoin: RedvixCoin Airdrop is now Live🚀💰🏆
#
# Click on below link to participate into this amazing #Airdrop🎁
#
# https://t.co/MAUN316yGn…
# UPDATE
#
# You can now Buy/sell #Bitcoin, $ETH $NANO instantly at zero risks by trading with our verified #Bigeria Age… https://t.co/PLxSpV0455
# RT @BTCIA: What $AMB price will go if $80B+ revenue company releases PR of collaboration in Q1 2020?🔥#Blockchain #Crypto #cryptocurrency #S…
# RT @RealCoinGeek: Ain’t no party like a CoinGeek party 🥳 🎈
#
# #BSV #Bitcoin #CGLondon https://t.co/10vI8aaWrC
# RT @JRNYcrypto: New video!
# ✅Bitcoin to $25,000 soon?
# ✅ETH + XRP Bridge!
# ✅Another step towards mass adoption
#
# Watch here: https://t.co/j0v9w…
# RT @SharkRadioNet: For this installment, Jim welcomes Ted Malloch to the show to discuss the Trump smear campaign, his interactions with th…
# @scottmelker To be fair, #bitcoin relies on people (eg, running mining rigs, producing them, operating power statio… https://t.co/pmQ0nmAyqH
# RT @Bitsahara: Weekends are for Stacking Sats!
#
# RT for 10,000 Sats on Lightning!
#
# 6 Winners in 3 Hours!⚡️
#
# Start Lightning: https://t.co/pE…
# RT @smart_stats: Crypto Fear/Greed Index:
#
# Status: Fear
# Value: 44/100
#
# #crypto #btc #bitcoin #fomo #pump #dump #SmartLiquidity
# ✅Join @Smart…
# Vodafone Includes Bitcoin in New Advert After Exiting Libra https://t.co/dtA1PucdCA
# RT @rogerkver: The reasons I started investing in Bitcoin in 2011 are the exact same reasons I’m investing in Bitcoin Cash today. https://t…
# RT @IrishGirlCrypt1: 🚨$50 #Bitcoin #Crypto #Giveaway🚨
#
# 🎁ONE PERSON GETS 0.0052 $BTC 🤑
#
# 🧜‍♀️Rules:
#
# ✅Like &amp; Retweet
#
# ✅Follow @Crypto_Guy_UK…
# Blaming #bitcoin for #ransomware attacks is like #blaming the #dollar when a #bank is #robbed.
# RT @Bitsahara: Weekends are for Stacking Sats!
#
# RT for 10,000 Sats on Lightning!
#
# 6 Winners in 3 Hours!⚡️
#
# Start Lightning: https://t.co/pE…
# RT @Bitsahara: Weekends are for Stacking Sats!
#
# RT for 10,000 Sats on Lightning!
#
# 6 Winners in 3 Hours!⚡️
#
# Start Lightning: https://t.co/pE…
# RT @JackKinLim: Me travelling back in time to 2006 to convince my parents that I'm their son from the future, and that they need to invest…
# RT @rBryer23: #Bitcoin isn’t even a once in a lifetime opportunity...
#
# This is a once in the history thus far of mankind opportunity ...
#
# #…
# RT @DTAPCAP: Just finished listening to interview of @RaoulGMI. I don't ever recall him singling out any investment that he thought would o…
# @LulzSecOps This cant be lulzsec, a bitcoin dont mean shit to me lmao. Real lulzsec wouldnt fucking follow a bunch… https://t.co/HYorixh0MW
# RT @SharingforCari1: #Bitcoin hits $10000 again !
# Let’s support this PUMP guys !
# 🎁100000 #Satoshi for someone🎁
#
# ✅Comment : #BTC to the mooo…
# This Chinese Whale Lost $45 Million in Bitcoin and BCH Overnight: How it Happened https://t.co/Hz4h3qrWdQ https://t.co/S4sUx3FI2r
# RT @_LegitAirdrops_: 🎁 FREE 30000 #CNG
#
# 📊 Market : #Coinsbit
#
# Register here: https://t.co/l6vu0X3zCm
#
# 💸 Estimated value: 35 USD
#
# ✅ Go to t…
# RT @ssaurel: 5 Reasons Why You Should Consider Ethereum Even if You Are a Bitcoiner #Ethereum #Bitcoin #Crypto #Cryptocurrencies #Cryptocur…
# #chainlink $link #bitcoin
# #PoweredByChainlink
#
# Yesterday:
#
# Chainlink Holders: 98,793
#
# Today:
#
# Chainlink Holders: 99,191
#
#  🚀🚀
# RT @EriBigeria: Hint 💡
#
# Musicians we're preparing a place for you @BigeriaExchange (Not your regular exchange eh? 😏)
#
# Music transcend life…
# #Bitcoin Customer Service Number 𝟏-𝟖𝟑𝟑-𝟒𝟎𝟗-𝟎𝟑𝟎𝟏
# #Blockchain customer service
# #Blockchain customer service number… https://t.co/XE03uzkVpF
# RT @IrishGirlCrypt1: 🚨$50 #Bitcoin #Crypto #Giveaway🚨
#
# 🎁ONE PERSON GETS 0.0052 $BTC 🤑
#
# 🧜‍♀️Rules:
#
# ✅Like &amp; Retweet
#
# ✅Follow @Crypto_Guy_UK…
# RT @EriBigeria: Volatility provides opportunity... #Bitcoin and #crypto is the future of finance.
#
# Learn more about #crypto for free on @Bi…
# RT @oddgems: My second #BITCOIN Giveaway!
#
# $100 in $BTC to 1 lucky winner.
#
# Rules:
# 🔥 Follow @PrimeXbt
# 🔥 Retweet &amp; Like this Tweet
#
# Please…
# RT @Social_Molly: Look at this complete #Infographic: the original #Blockchain Uses cases
#
# #Analytics #DigitalTransformation #ArtificialInt…
# @I_Am_ICT gun trade #bitcoin, $100 or $100k? 🧐
# Bitcoin and Beyond: Other Cryptocurrencies With The Highest Market Capitalisation Part 1. https://t.co/Z9MiCbhIAp
# @jim_bowley @BitcoinDynamics @Patrice_Gaucher @MindoMax @oudekaas3 During my research, I found out that BTC is actu… https://t.co/eS2xsLnFw3
# RT @APompliano: There are 40,000+ investors, entrepreneurs, and developers all reading the same letter every morning analyzing Bitcoin, blo…
# Good morning. For last 12 days we have been seeing a 2-3 day price rotation. New @StanislavDessos  levels have alre… https://t.co/n4nreDLlei
# RT @BTCIA: What $AMB price will go if $80B+ revenue company releases PR of collaboration in Q1 2020?🔥#Blockchain #Crypto #cryptocurrency #S…
# 💗Not just #Yahoo mentioned $AMB Ambrosus with #IBM $IBM  multiple times $80 Billion collaboration pending❤️❤️… https://t.co/FMjg6t4juK
# Feb 22, 2020: The current Mayer Multiple is 1.09 with a $BTC price of $USD 9,621.52 and a 200 day moving average of… https://t.co/8agKEv0SAq
# RT @Blocks991: PundiX recently announced its collaboration with MakerDAO to enable merchants to receive free XPOS® devices to sell and acce…
# RT @gernot_lechner: "Bitcoin is less volatile from a systemic perspective than I think the traditional financial industry is," says the Wyo…
# How do you keep a virus out of production? by constantly testing your BITCOIN after every the end of the world!
# RT @ManiGon33453061: The love of the child for the mother #mother #momlife #propagandalive #Bitcoin #chesuccede #ALDUBxADNPragma #Zombies2…
# RT @dinfomall: #business #news #tech #technology #gamedev #bitcoin #today #indiedev #crypto Today's Deal! https://t.co/fMdsSy6xlM
# The coin noise when your transaction hits your @exodus_io wallet startles me every time, but am then delighted to s… https://t.co/2x51r73kna
# RT @IrishGirlCrypt1: 🚨$50 #Bitcoin #Crypto #Giveaway🚨
#
# 🎁ONE PERSON GETS 0.0052 $BTC 🤑
#
# 🧜‍♀️Rules:
#
# ✅Like &amp; Retweet
#
# ✅Follow @Crypto_Guy_UK…
# RT @stakecube: 🤑#Altbet &amp; #StakeCube  #GIVEAWAY! 🤑
#
#  🏆[3x] 500 $ABET each &amp;
#  🏆[3x] 100 $SCC each
#
# Here's how to play:
# 1⃣ Follow @StakeCube…
# @houstonwecool @coinbase @tezos Bitcoin price gonna go down a little bit, and there won't be any "pump"
# RT @solarypto: 🔥🔥🔥🔥🔥🔥‼️‼️📣 SOLARYPTO’S ITO HAS STARTED!!! 🕺 💃💰💰 Hurry Up................
# #crypto #bitcoin #cryptocurrency #btc #ethereum ht…
# How people are reacting on bitcoin by analyzing 100 Tweets.
# Positive
